# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

from TurkishStemmer import TurkishStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re

# %% [markdown]
# ## This is the test run: How well does the scraper script do on one song?

# %%
url = 'http://sarki.alternatifim.com/sarkici/sezen-aksu/1980'
results = requests.get(url)

soup = BeautifulSoup(results.content, 'lxml')

artist_and_song_title = soup.find('h3', {'class':'baslik'}).text

artist = artist_and_song_title.split('-')[0].strip()
song_title = artist_and_song_title.split('-')[1].strip()

album_title = soup.find('tr').find('td', {'style':None}).text

song_text = soup.find('div', {"class":'sarkisozu'}).text

song_text = song_text[:song_text.find('*')].replace('\r', '').replace('\n', '').replace('/','')

print("Artist: ", artist)
print("Song Title: ", song_title)
print("Album: ", album_title)

artist_col = []
title_col = []
album_col = []
text_col = []

artist_col.append(artist)
title_col.append(song_title)
album_col.append(album_title)
text_col.append(song_text)

pd.DataFrame({
    'artist': artist_col,
    'title': title_col,
    'album': album_col,
    'text': text_col
})
# Out:
# Artist:  Sezen Aksu
# Song Title:  1980
# Album:  1980
#        artist title album                                               text
# 0  Sezen Aksu  1980  1980  Sigaramın dumanına sarsam saklasam seni Gitme ...

# %%
test_text = song_text.title()

# %%
test_text
# Out:
# 'Sigaramın Dumanına Sarsam Saklasam Seni Gitme Gitme Gittiğin Yollardan Dönülmez Geri Gitme Gitme El Olursun Sevdiğim Incitir Beni  Yokluğun Ah Yol Yol Olsa Uzasa Unutmam Seni Gitme Gitme Gittiğin Yollardan Dönülmez Geri Gitme Gitme El Olursun Sevdiğim Incitir Beni  Akşam Vakti Sardı Yine Hüzünler Kalbim Yangın Yeri Gel Kurtar Beni Senden Akşam Vakti Dolaştım Sokaklarda Yırtık Bir Afiş Seni Gördüm Duvarda  Sigaramın Dumanına Sarsam Saklasam Seni Yokluğun Ah Yol Yol Olsa Uzasa Unutmam Seni Gitme Gitme Gittiğin Yollardan Dönülmez Geri Gitme Gitme El Olursun Sevdiğim Incitir Beni'

# %%
def text_process(text):
    '''
    Takes in a string of text, then performs the following:
        1. Tokenizes and removes punctuation
        2. Removes stopwords
        3. Stems
        4. Returns a list of the cleaned text
    '''
    if pd.isnull(text):
        return []
    # tokenizing and removing punctuation
    tokenizer = RegexpTokenizer(r'\w+')
    text_processed=tokenizer.tokenize(text)
    
    # removing any stopwords
    text_processed = [word.lower() for word in text_processed if word.lower() not in stopwords.words('turkish')]
    
    # stemming
    stemmer = TurkishStemmer()
    
    text_processed = [stemmer.stem(word) for word in text_processed]
    
    try:
        text_processed.remove('b')
    except: 
        pass

    return " ".join(text_processed) ## <-- we're keeping our words distinct

# %%
text_process(test_text)
# Out:
# 'sigara duman sar sakl sen git git gittik yol dönülmez ger git git el olur sevdik inci ben yokluk ah yol yol ols uzas unutma sen git git gittik yol dönülmez ger git git el olur sevdik inci ben akşa vakti sart yin hüz kalbim yang yer gel kurtar ben sen akşa vakti dolaş sokak yır bir afiş sen gört duvar sigara duman sar sakl sen yokluk ah yol yol ols uzas unutma sen git git gittik yol dönülmez ger git git el olur sevdik inci ben'

# %% [markdown]
# ## Now testing the scraper for getting song names from one page:

# %%
url = 'http://sarki.alternatifim.com/sarkici/sezen-aksu/sayfa-1'
results = requests.get(url)
if results.status_code !='200':
    pass
soup = BeautifulSoup(results.content, 'lxml')

list_items = soup.find('ul').find_all('li')

this_list = [i.find('a').attrs['href'] for i in list_items]

print("Scraped {} song URLS from this page. ".format(len(this_list)))
# Out:
# Scraped 25 song URLS from this page.

# %% [markdown]
# ## Building a master list for Sezen Aksu song URLs on this site:

# %%
master_list = []
for i in range(1,8):
    url = 'http://sarki.alternatifim.com/sarkici/sezen-aksu/sayfa-' + str(i)
    results = requests.get(url)
    if results.status_code !='200':
        pass
    soup = BeautifulSoup(results.content, 'lxml')
    list_items = soup.find('ul').find_all('li')
    this_list = [i.find('a').attrs['href'] for i in list_items]
    master_list += this_list

print("Scraped {} songs for Sezen Aksu on this site.".format(len(master_list)))
# Out:
# Scraped 171 songs for Sezen Aksu on this site.

# %% [markdown]
# ## Here's the scraper script using the master list generated above.

# %%
artist_col = []
title_col = []
album_col = []
text_col = []


for item in master_list:
    url = 'http://sarki.alternatifim.com' + item
    results = requests.get(url)
    if results.status_code != '200':
        print('Error in scraping from', item)
        pass
    soup = BeautifulSoup(results.content, 'lxml')
    important_content = soup.find('div', {'class': 'ten columns cleft yazim'})
    title_info = important_content.find('div', {'class':'cbottom'})
    artist_and_song_title = title_info.find('h3').text
    artist = artist_and_song_title.split('-')[0].strip()
    song_title = artist_and_song_title.split('-')[1].strip()
    try:
        album_title = title_info.find('table').find('tbody').find('tr').find_all('td')[2].text
    except:
        album_title = np.nan
        
    song_text = important_content.find('div', {"class":'sarkisozu'}).text

    song_text = song_text[:song_text.find('/*')].replace('\r', ' ').replace('\n', '  ').replace('/',' ')
    artist_col.append(artist)
    title_col.append(song_title)
    album_col.append(album_title)
    text_col.append(song_text)

# %% [markdown]
# ## Putting this into a DataFrame:

# %%
df = pd.DataFrame({
    'artist': artist_col,
    'title': title_col,
    'album': album_col,
    'text': text_col
})

# %% [markdown]
# ## Building the scraper, there was a built-in way to add NAs when the album wasn't there. That information seems to be the most commonly missing.

# %%
# df.isna().sum()

# df['album'].value_counts()

# %%
df[(df['album']=='Allahaısmarladık') | (df['album']=='Allahaısmarladık (1977)')]
# Out:
#          artist                   title                    album  \
# 16   Sezen Aksu               Alev Alev  Allahaısmarladık (1977)
# 18   Sezen Aksu        Allahaısmarladık         Allahaısmarladık
# 19   Sezen Aksu             Allahaşkına         Allahaısmarladık
# 20   Sezen Aksu           Allahın Varsa         Allahaısmarladık
# 36   Sezen Aksu          Bir Kış Masalı         Allahaısmarladık
# 53   Sezen Aksu               Geçen Yaz  Allahaısmarladık (1977)
# 69   Sezen Aksu      Gözlerindeki Bulut  Allahaısmarladık (1977)
# 81   Sezen Aksu            İlk Gün Gibi         Allahaısmarladık
# 126  Sezen Aksu  Seni Gidi Vurdumduymaz         Allahaısmarladık
# 144  Sezen Aksu            Söyle Kimsin  Allahaısmarladık (1977)
# 157  Sezen Aksu       Uzun Lafın Kısası  Allahaısmarladık (1977)
# 166  Sezen Aksu                 Yalancı         Allahaısmarladık
#
#                                                   text
# 16      Ellerin ne kadar sıcak Tıpkı ateş gibi Bakı...
# 18      Yıllar yılı seviştik de neden mutlu olmadık...
# 19      Sen istedin diye değil seni sevdiğim için S...
# 20      Yaz bitti yine mevsim sonbahar Kim çeker ki...
# 36      Bir su damlası ürperir tenimde Bir temas ha...
# 53      İşte geçti bir yaz daha Geçti gitti rüzgar ...
# 69      Gözlerinde bir bulut var bugün Sanki bir şe...
# 81      Gitsen de olur söylemem Söylemem tek bir ke...
# 126     Bu kaçıncı ayrılışın bakmadan gözyaşıma  Bı...
# 144     Sen bir rüya bir resimsin Bir heyecan bir i...
# 157     Gittin artık sevgilim, sensiz kaldı burası ...
# 166     Çok söylediler bana çok söylediler Dinletem...

# %% [markdown]
# ## A scraper for getting year and track data on each album
# The album part of the scraper seem particularly bad.
# I'm going to access the discogs API to make a second

# %%
endpoint = 'https://api.discogs.com/artists/97253/releases'

result = requests.get(endpoint)

sezen = result.json()

sezen.keys()

discography_df = pd.DataFrame(sezen['releases'])

discography_df.columns

disc_df = discography_df[['title','year','resource_url']]

# for endpoint in discography_df['resource_url']:
#     res = requests.get(endpoint)
#     res_json = res.json()
    
endpoint = 'https://api.discogs.com/releases/7156101'
res = requests.get(endpoint)
res_json = res.json()

a = pd.DataFrame(res_json['tracklist'])

a
# Out:
#   duration position         title  type_
# 0                 A  Haydi Sansim  track
# 1                 B      Gel Bana  track

# %% [markdown]
# Process:
# - I have a dataframe with the following important information: title, year, and resource_url
# - Each resource_url leads to an api endpoint with a tracklist key
# - I want a dataframe with columns album, year, track_title

# %%
disc_df.head(2)
# Out:
#                               title  year  \
# 0           Haydi Sansim / Gel Bana  1975
# 1  Kusura Bakma / Yaşanmamış Yıllar  1976
#
#                                resource_url
# 0  https://api.discogs.com/releases/7156101
# 1  https://api.discogs.com/releases/2359231

# %%
# # This script is meant to make the discography for sezen aksu. It takes some time so it also saves the dataframe.

# import time

# df_tracks = pd.DataFrame({
#   'title':[],
#   'album':[],
#   'year':[]
# })
# for i in range(disc_df.shape[0]):
# #     print(disc_df.iloc[i,:]['resource_url'])
#     this_endpoint = disc_df.iloc[i,:]['resource_url']
#     this_album = disc_df.iloc[i,:]['title']
#     this_year = disc_df.iloc[i,:]['year']
#     res = requests.get(this_endpoint)
#     res_json = res.json()
# #     print(res_json['tracklist'])
#     this_tracklist = pd.DataFrame(res_json['tracklist'])
# #     print(this_tracklist)
#     this_tracklist['album'] = this_album
#     this_tracklist['year'] = str(this_year)
#     try:
#         this_tracklist = this_tracklist.drop(['duration','position','type_','extraartists'], axis  = 1)
#     except:
#         this_tracklist = this_tracklist.drop(['duration','position','type_'], axis  = 1)
#     print("Adding {} to dataframe...".format(this_album))
#     print("Columns: {}".format(this_tracklist.columns))
#     print('\n')
#     df_tracks = df_tracks.append(this_tracklist, sort=True)
#     time.sleep(3)

# df_tracks.to_csv('sezen_discog.csv')

# %%
df_tracks = pd.read_csv('sezen_discog.csv', index_col = 0)

# %%
df_tracks.columns
# Out:
# Index(['album', 'title', 'year'], dtype='object')

# %%
for item in df['title']:
    if item in set(df_tracks['title']):
        print(item)
# Out:
# Ablam Aşktan Öldü
# Adem Olan Anlar
# Adı Menekşe
# Ağlamak Güzeldir
# Ah Mazi
# Ahdım Olsun
# Akasyalar Açarken
# Alev Alev
# Ali
# Allahaısmarladık
# Allahın Varsa
# Aşk
# Beşik
# Bırak Beni
# Bile Bile
# Biliyorsun
# Bir Acı Kahvenin
# Bir Başka Aşk
# Bir Çocuk Sevdim
# Bir Kuş Uçur
# Bir Zamanlar Deli Gönlüm
# Bu Gece
# Çile
# Çocuk
# Çocuklar Gibi
# Farkındayım
# Firuze
# Gamsız
# Geçen Yaz
# Geçer
# Geçiyor Bizden De
# Gel Bana
# Gelen Gideni Aratır
# Geri Dön
# Gidemem
# Gidiyorum
# Gidiyorum Bu Şehirden
# Git
# Gölge Etme
# Gözlerindeki Bulut
# Gözlerine Göz Değmiş
# Gül
# Güllerim Soldu
# Gülümse
# Gün Gelir
# İçime Sinmiyor
# İkili Delilik
# İkinci Bahar
# İlk Gün Gibi
# İnce Mevzu
# İstanbul Hatırası
# İstanbul İstanbul Olalı
# Kaç Yıl Geçti Aradan
# Kaçın Kurası
# Kaderim
# Kahpe Kader
# Kalaşnikof
# Kalbim Ege'de Kaldı
# Kalp Unutmaz
# Kutlama
# Küçüğüm
# Küçük Yaz Çiçeği
# Le Le Le
# Lunapark
# Masum Değiliz
# Memet
# Menajer
# Minik Serçe
# Namus
# Ne Ağlarsın
# Ne Kavgam Bitti Ne Sevdam
# Neye Yarar
# Nihayet
# O Sensin
# Seni Gidi Vurdumduymaz
# Seni İstiyorum
# Seni Kimler Aldı
# Seni Yerler
# Sensizim
# Sızı
# Silemezler Gönlümden
# Son Bakış
# Son Sardunyalar
# Sonbahar
# Sor Beni
# Söyle Kimsin
# Su Gibi
# Sude
# Sultan Süleyman
# Tükeneceğiz
# Unut
# Uzaklarda Bir Çizgide
# Uzun Lafın Kısası
# Ünzile
# Var Git Turnam
# Vazgeçtim
# Yak Bir Sigara
# Yaktılar Halim'imi
# Yalancı
# Yalancı Dünya
# Yalnız Kullar (Tanrım)
# Yalnızca Sitem
# Yalnızlık Senfonisi

# %%
df_merged = df.merge(df_tracks, how = 'left', on = 'title')

# %%
df_merged.columns
# Out:
# Index(['artist', 'title', 'album_x', 'text', 'album_y', 'year'], dtype='object')

# %%
df_merged.drop('album_y', axis = 1, inplace=True)

# %%
df_merged.columns = ['artist','title','album','text','year']

# %%
df_clean = df_merged[pd.notnull(df_merged['year'])]
df_clean['year'] = df_clean['year'].astype(int)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_clean
# Out:
#          artist                   title                         album  \
# 2    Sezen Aksu       Ablam Aşktan Öldü          şarkı söylemek lazım
# 5    Sezen Aksu         Adem Olan Anlar            Deli Kızın Türküsü
# 6    Sezen Aksu         Adem Olan Anlar            Deli Kızın Türküsü
# 8    Sezen Aksu             Adı Menekşe               Adı Bende Saklı
# 9    Sezen Aksu        Ağlamak Güzeldir              Ağlamak Güzeldir
# 12   Sezen Aksu                 Ah Mazi                           Git
# 13   Sezen Aksu                 Ah Mazi                           Git
# 14   Sezen Aksu                 Ah Mazi                           Git
# 15   Sezen Aksu             Ahdım Olsun                        Bahane
# 16   Sezen Aksu       Akasyalar Açarken                  Serçe (1978)
# 17   Sezen Aksu       Akasyalar Açarken                  Serçe (1978)
# 20   Sezen Aksu               Alev Alev       Allahaısmarladık (1977)
# 21   Sezen Aksu               Alev Alev       Allahaısmarladık (1977)
# 22   Sezen Aksu               Alev Alev       Allahaısmarladık (1977)
# 23   Sezen Aksu               Alev Alev       Allahaısmarladık (1977)
# 24   Sezen Aksu                     Ali                 Sezen Aksu 88
# 25   Sezen Aksu                     Ali                 Sezen Aksu 88
# 26   Sezen Aksu                     Ali                 Sezen Aksu 88
# 27   Sezen Aksu                     Ali                 Sezen Aksu 88
# 28   Sezen Aksu        Allahaısmarladık              Allahaısmarladık
# 29   Sezen Aksu        Allahaısmarladık              Allahaısmarladık
# 30   Sezen Aksu        Allahaısmarladık              Allahaısmarladık
# 31   Sezen Aksu        Allahaısmarladık              Allahaısmarladık
# 33   Sezen Aksu           Allahın Varsa              Allahaısmarladık
# 37   Sezen Aksu                     Aşk                           Aşk
# 38   Sezen Aksu                     Aşk                           Aşk
# 40   Sezen Aksu                   Beşik                 Deniz yıldızı
# 43   Sezen Aksu              Bırak Beni                        Bahane
# 44   Sezen Aksu              Bırak Beni                        Bahane
# 45   Sezen Aksu               Bile Bile   Yürüyorum Düş Bahçeleri'nde
# ..          ...                     ...                           ...
# 228  Sezen Aksu             Tükeneceğiz               ferdibaba_fatih
# 230  Sezen Aksu                    Unut                           NaN
# 231  Sezen Aksu                    Unut                           NaN
# 232  Sezen Aksu                    Unut                           NaN
# 236  Sezen Aksu   Uzaklarda Bir Çizgide           Sevgilerimle (1980)
# 237  Sezen Aksu       Uzun Lafın Kısası       Allahaısmarladık (1977)
# 238  Sezen Aksu       Uzun Lafın Kısası       Allahaısmarladık (1977)
# 239  Sezen Aksu       Uzun Lafın Kısası       Allahaısmarladık (1977)
# 241  Sezen Aksu                  Ünzile                            88
# 242  Sezen Aksu                  Ünzile                            88
# 243  Sezen Aksu                  Ünzile                            88
# 244  Sezen Aksu                  Ünzile                            88
# 245  Sezen Aksu                  Ünzile                            88
# 246  Sezen Aksu                  Ünzile                            88
# 247  Sezen Aksu          Var Git Turnam  Işık Doğudan Yükselir (1995)
# 249  Sezen Aksu               Vazgeçtim                       Gülümse
# 250  Sezen Aksu               Vazgeçtim                       Gülümse
# 251  Sezen Aksu               Vazgeçtim                       Gülümse
# 253  Sezen Aksu          Yak Bir Sigara                           NaN
# 254  Sezen Aksu          Yak Bir Sigara                           NaN
# 255  Sezen Aksu      Yaktılar Halim'imi                           NaN
# 256  Sezen Aksu                 Yalancı              Allahaısmarladık
# 257  Sezen Aksu                 Yalancı              Allahaısmarladık
# 258  Sezen Aksu                 Yalancı              Allahaısmarladık
# 259  Sezen Aksu           Yalancı Dünya                           NaN
# 260  Sezen Aksu           Yalancı Dünya                           NaN
# 261  Sezen Aksu  Yalnız Kullar (Tanrım)       Ağlamak Güzeldir (1981)
# 262  Sezen Aksu          Yalnızca Sitem                           NaN
# 263  Sezen Aksu          Yalnızca Sitem                           NaN
# 264  Sezen Aksu     Yalnızlık Senfonisi                           NaN
#
#                                                   text  year
# 2       Ablam aşktan öldü Herşey filmlerdeki gibi o...  2002
# 5       Ben bu dünyaya bir türlü alışamadım Bu yüzd...  1993
# 6       Ben bu dünyaya bir türlü alışamadım Bu yüzd...  2007
# 8       Bu şehrin meydanlarında, garında, rıhtımınd...  1998
# 9       Aglamak guzeldir Suzulurken yaslar gozunden...  1981
# 12      Titresin bir mum alevinde o eski günler  Bi...  1990
# 13      Titresin bir mum alevinde o eski günler  Bi...  2007
# 14      Titresin bir mum alevinde o eski günler  Bi...  2008
# 15      Geçti yıllar ah geç aydım Anladım ki boşa g...  2005
# 16      Yar yolunu kolladım İpek mendil salladım On...  1978
# 17      Yar yolunu kolladım İpek mendil salladım On...  2008
# 20      Ellerin ne kadar sıcak Tıpkı ateş gibi Bakı...  1977
# 21      Ellerin ne kadar sıcak Tıpkı ateş gibi Bakı...  2000
# 22      Ellerin ne kadar sıcak Tıpkı ateş gibi Bakı...  2007
# 23      Ellerin ne kadar sıcak Tıpkı ateş gibi Bakı...  2008
# 24      Namluna dayanır yola dalarsın Durusun bakıs...  1986
# 25      Namluna dayanır yola dalarsın Durusun bakıs...  1990
# 26      Namluna dayanır yola dalarsın Durusun bakıs...  1997
# 27      Namluna dayanır yola dalarsın Durusun bakıs...  1997
# 28      Yıllar yılı seviştik de neden mutlu olmadık...  1977
# 29      Yıllar yılı seviştik de neden mutlu olmadık...  1977
# 30      Yıllar yılı seviştik de neden mutlu olmadık...  2007
# 31      Yıllar yılı seviştik de neden mutlu olmadık...  2008
# 33      Yaz bitti yine mevsim sonbahar Kim çeker ki...  1997
# 37      Bak yağıyor yağmur  Her damlada gözlerin  B...  1978
# 38      Bak yağıyor yağmur  Her damlada gözlerin  B...  2008
# 40      Beşik  Buraya bu acı çekmeye geldik Hazdan ...  2008
# 43      Bırak beni yeter aldattığın yeter bırak ben...  1989
# 44      Bırak beni yeter aldattığın yeter bırak ben...  1990
# 45      Bir arada olabilmek ne mümkün Bir arada kal...  1996
# ..                                                 ...   ...
# 228     Ne böyle senle ne de sensiz yazık yaşanmıyo...  1984
# 230     Kolay olmayacak  elbet üzeleceğiz mutlaka b...  1988
# 231     Kolay olmayacak  elbet üzeleceğiz mutlaka b...  1990
# 232     Kolay olmayacak  elbet üzeleceğiz mutlaka b...  1997
# 236     Bir martı tek başına uçuyordu maviliklerde ...  1980
# 237     Gittin artık sevgilim, sensiz kaldı burası ...  1977
# 238     Gittin artık sevgilim, sensiz kaldı burası ...  2007
# 239     Gittin artık sevgilim, sensiz kaldı burası ...  2008
# 241     Ünzile insan dölü On kardeş beşi ölü Büyüdü...  1986
# 242     Ünzile insan dölü On kardeş beşi ölü Büyüdü...  1990
# 243     Ünzile insan dölü On kardeş beşi ölü Büyüdü...  1997
# 244     Ünzile insan dölü On kardeş beşi ölü Büyüdü...  2005
# 245     Ünzile insan dölü On kardeş beşi ölü Büyüdü...  2007
# 246     Ünzile insan dölü On kardeş beşi ölü Büyüdü...  2008
# 247     Dağlar dağlar dumanlı dağlar Yücelerinde er...  1995
# 249     Vazgeçtim gözlerinden Vazgeçtim sözlerinden...  1991
# 250     Vazgeçtim gözlerinden Vazgeçtim sözlerinden...  2007
# 251     Vazgeçtim gözlerinden Vazgeçtim sözlerinden...  2008
# 253     Seni ilk gördüğümde tırnaklarını yiyordun  ...  1981
# 254     Seni ilk gördüğümde tırnaklarını yiyordun  ...  1999
# 255     Martılar havalandı çığlık çığlığa  Bir ağıt...  1995
# 256     Çok söylediler bana çok söylediler Dinletem...  1979
# 257     Çok söylediler bana çok söylediler Dinletem...  1989
# 258     Çok söylediler bana çok söylediler Dinletem...  2000
# 259     Hem okudum hem yazdım Bir düz oturdum bir a...  2000
# 260     Hem okudum hem yazdım Bir düz oturdum bir a...  2007
# 261     Tanrım tek başına koyma kulların Yalnızlığa...  1981
# 262     Vurgun yemiş misali gönlüm tutuldu aşka  Ci...  1986
# 263     Vurgun yemiş misali gönlüm tutuldu aşka  Ci...  1990
# 264     Anladım sonu yok yalnızlığın Hergün çoğalac...  1996
#
# [197 rows x 5 columns]

# %% [markdown]
# Problems:
# - lots of doubled songs. How can I just keep the earlier date?

# %%
df_clean = df_clean.sort_values('year', ascending=False).drop_duplicates(subset = ['title','text'], keep = 'last')

# %% [markdown]
# ## Now time to tokenize

# %%
corpus = df_clean['text'].map(text_process)

# %%
corpus[216]
# Out:
# 'lâl ol dil ben sen sor ben dak sır ol söz ben kulak ver rüzgârlara kent bul sen ben kent bil sen ben i̇ster yüz sür yağmur i̇ster anlat su kar kapa yol yol sor kar sorm kent bul sen ben kent bil sen ben lâl ol dil ben sen sor ben dak dünya sarhoş çocuk google_ad_client ca pub 7620071422727774'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords


cvec = CountVectorizer(stop_words=stopwords.words("turkish") + ['bir'])

# %%
cvec.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=['acaba', 'ama', 'aslında', 'az', 'bazı', 'belki', 'biri', 'birkaç', 'birşey', 'biz', 'bu', 'çok', 'çünkü', 'da', 'daha', 'de', 'defa', 'diye', 'eğer', 'en', 'gibi', 'hem', 'hep', 'hepsi', 'her', 'hiç', 'için', 'ile', 'ise', 'kez', 'ki', 'kim', 'mı', 'mu', 'mü', 'nasıl', 'ne', 'neden', 'nerde', 'nerede', 'nereye', 'niçin', 'niye', 'o', 'sanki', 'şey', 'siz', 'şu', 'tüm', 've', 'veya', 'ya', 'yani', 'bir'],
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
transformed_corpus = cvec.transform(corpus)

# %%
word_table = pd.DataFrame(transformed_corpus.todense(), columns = cvec.get_feature_names()).drop(['7620071422727774', 'google_ad_client'], axis = 1)

# %%
word_table.describe()
# Out:
#               aah       aahhh        abla      acelen        acem         acı  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     0.019417    0.009709    0.009709    0.009709    0.009709    0.058252
# std      0.197066    0.098533    0.098533    0.098533    0.098533    0.307592
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      2.000000    1.000000    1.000000    1.000000    1.000000    2.000000
#
#              acık        acıl    acılanma    acılaşır     ...           şeref  \
# count  103.000000  103.000000  103.000000  103.000000     ...      103.000000
# mean     0.009709    0.009709    0.009709    0.009709     ...        0.009709
# std      0.098533    0.098533    0.098533    0.098533     ...        0.098533
# min      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 25%      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 50%      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 75%      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# max      1.000000    1.000000    1.000000    1.000000     ...        1.000000
#
#            şeytan        şiir    şikayets       şimdi        şimt         şiş  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     0.019417    0.029126    0.019417    0.019417    0.213592    0.009709
# std      0.138662    0.168983    0.197066    0.138662    0.800128    0.098533
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    2.000000    1.000000    6.000000    1.000000
#
#               şte       şubat        şöyl
# count  103.000000  103.000000  103.000000
# mean     0.029126    0.009709    0.009709
# std      0.168983    0.098533    0.098533
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000
#
# [8 rows x 1875 columns]

# %%
pd.DataFrame(word_table.sum()).sort_values(by = 0, ascending = False)
# Out:
#               0
# sen         142
# ben         121
# pub          74
# ca           74
# gün          51
# göz          51
# var          50
# zaman        38
# gel          38
# olur         38
# git          38
# aşk          37
# ban          37
# ah           36
# ger          34
# dünya        33
# le           32
# yer          32
# dön          30
# bum          30
# yol          29
# kadar        29
# kent         27
# yıl          27
# yürek        25
# son          25
# san          24
# al           24
# ar           24
# baş          23
# ...         ...
# incinme       1
# inanm         1
# kalem         1
# inanki        1
# inandırma     1
# inandık       1
# in            1
# imtihan       1
# imkansiz      1
# imkan         1
# isler         1
# istedik       1
# istemiyor     1
# itiraf        1
# kalbi         1
# kalan         1
# kalabilmek    1
# kalabilir     1
# kala          1
# kahvereng     1
# kahrediyor    1
# kahre         1
# kafir         1
# kadı          1
# kadeh         1
# içme          1
# içki          1
# izler         1
# iyonya        1
# şöyl          1
#
# [1875 rows x 1 columns]
